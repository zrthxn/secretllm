# %% [markdown]
# # Optimizing image generation prompting using CLIP scores
# In this notebook we will compare different prompts and measure a text-to-image similarity metric: The [CLIP score](https://lightning.ai/docs/torchmetrics/stable/multimodal/clip_score.html).

# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from diffusers import DiffusionPipeline, AutoencoderTiny

# %% [markdown]
# This is how the metric is initialized

# %%
from torchmetrics.multimodal.clip_score import CLIPScore
metric = CLIPScore(model_name_or_path="/projects/p_scads_llm_secrets/models/clip-vit-base-patch16")

# %% [markdown]
# We start with this example image.

# %%
image = Image.open("data/real_cat.png")
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 image = Image.open("data/real_cat.png")
#       2 plt.imshow(image)
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/real_cat.png'

# %%
score = metric(torch.as_tensor(image), "cat")
score.detach()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 score = metric(torch.as_tensor(image), "cat")
#       2 score.detach()
#
# NameError: name 'image' is not defined

# %%
score = metric(torch.as_tensor(image), "microscope")
float(score.detach())
# Out:
# 30.786287307739258

# %% [markdown]
# ## Recap: Generating images
# We will now use a prompt to generate an image and will measure if it shows a cat.

# %%
pipe = DiffusionPipeline.from_pretrained(
    "/projects/p_scads_llm_secrets/models/stable-diffusion-2-1-base", torch_dtype=torch.float16
)
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pipe = DiffusionPipeline.from_pretrained(
#       2     "/projects/p_scads_llm_secrets/models/stable-diffusion-2-1-base", torch_dtype=torch.float16
#       3 )
#       4 pipe = pipe.to("cuda")
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/diffusers/pipelines/pipeline_utils.py:924, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     921     loaded_sub_model = passed_class_obj[name]
#     922 else:
#     923     # load sub model
# --> 924     loaded_sub_model = load_sub_model(
#     925         library_name=library_name,
#     926         class_name=class_name,
#     927         importable_classes=importable_classes,
#     928         pipelines=pipelines,
#     929         is_pipeline_module=is_pipeline_module,
#     930         pipeline_class=pipeline_class,
#     931         torch_dtype=torch_dtype,
#     932         provider=provider,
#     933         sess_options=sess_options,
#     934         device_map=current_device_map,
#     935         max_memory=max_memory,
#     936         offload_folder=offload_folder,
#     937         offload_state_dict=offload_state_dict,
#     938         model_variants=model_variants,
#     939         name=name,
#     940         from_flax=from_flax,
#     941         variant=variant,
#     942         low_cpu_mem_usage=low_cpu_mem_usage,
#     943         cached_folder=cached_folder,
#     944         use_safetensors=use_safetensors,
#     945     )
#     946     logger.info(
#     947         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#     948     )
#     950 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/diffusers/pipelines/pipeline_loading_utils.py:725, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors)
#     723 # check if the module is in a subdirectory
#     724 if os.path.isdir(os.path.join(cached_folder, name)):
# --> 725     loaded_sub_model = load_method(os.path.join(cached_folder, name), **loading_kwargs)
#     726 else:
#     727     # else load from the root directory
#     728     loaded_sub_model = load_method(cached_folder, **loading_kwargs)
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/diffusers/models/modeling_utils.py:901, in ModelMixin.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     893 if len(missing_keys) > 0:
#     894     raise ValueError(
#     895         f"Cannot load {cls} from {pretrained_model_name_or_path} because the following keys are"
#     896         f" missing: \n {', '.join(missing_keys)}. \n Please make sure to pass"
#     897         " `low_cpu_mem_usage=False` and `device_map=None` if you want to randomly initialize"
#     898         " those weights or else make sure your checkpoint file is correct."
#     899     )
# --> 901 unexpected_keys = load_model_dict_into_meta(
#     902     model,
#     903     state_dict,
#     904     device=param_device,
#     905     dtype=torch_dtype,
#     906     model_name_or_path=pretrained_model_name_or_path,
#     907     hf_quantizer=hf_quantizer,
#     908     keep_in_fp32_modules=keep_in_fp32_modules,
#     909 )
#     911 if cls._keys_to_ignore_on_load_unexpected is not None:
#     912     for pat in cls._keys_to_ignore_on_load_unexpected:
#
# File /projects/p073/p_scads_llm_secrets/kernel/lib/python3.10/site-packages/diffusers/models/model_loading_utils.py:215, in load_model_dict_into_meta(model, state_dict, device, dtype, model_name_or_path, hf_quantizer, keep_in_fp32_modules)
#     213         set_module_kwargs["dtype"] = torch.float32
#     214 else:
# --> 215     param = param.to(dtype)
#     216     if accepts_dtype:
#     217         set_module_kwargs["dtype"] = dtype
#
# KeyboardInterrupt:

# %%
prompt = "Draw a realistic photo of a cat."

cat = pipe(prompt).images[0]
cat
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# C:\Users\haase\mambaforge\envs\tea4\lib\site-packages\diffusers\models\attention_processor.py:1117: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   hidden_states = F.scaled_dot_product_attention(
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
score = metric(torch.as_tensor(np.array(cat)), "cat")
np.asarray(score.detach())
# Out:
# array(28.016827, dtype=float32)

# %% [markdown]
# ## Benchmarking prompts
# To compare different prompts quantitatively, we run image generation in a loop and measure their quality. As a control, we also generate images that show dogs and no cats.
#
# Using this strategy, we can do prompt engineering / prompt optimization in an informed way.

# %%
num_attempts = 10
prompts = ["Draw a realistic photo of a cat.", 
           "Draw a cat",
           "cat", 
           "Draw a realistic photo of a dog."]

data = {"prompt":[],
        "score":[]}
for prompt in prompts:
    for i in range(num_attempts):
        image = pipe(prompt).images[0]

        score = metric(torch.as_tensor(np.array(image)), "cat")
        data["score"].append(float(score.detach()))
        data["prompt"].append(prompt)

        print(f"{prompt}: {score}")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 26.941282272338867
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 26.68951416015625
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 28.38190460205078
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 27.159305572509766
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 27.855777740478516
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 27.731395721435547
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 26.555828094482422
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 27.467601776123047
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 27.05622673034668
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a cat.: 26.07479476928711
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 28.109989166259766
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 27.181486129760742
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 28.063491821289062
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 27.581003189086914
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 26.792367935180664
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 25.883220672607422
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 27.59506607055664
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 27.134281158447266
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 27.220333099365234
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a cat: 29.248836517333984
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 26.893535614013672
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 20.41377067565918
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 28.067102432250977
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 20.126529693603516
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 17.784080505371094
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 27.820131301879883
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 26.091835021972656
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 27.251890182495117
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 20.15304946899414
#   0%|          | 0/50 [00:00<?, ?it/s]
# cat: 18.186676025390625
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.072940826416016
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.035152435302734
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 19.988601684570312
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 19.391700744628906
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 19.793643951416016
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.654407501220703
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.193735122680664
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 21.033754348754883
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.90523338317871
#   0%|          | 0/50 [00:00<?, ?it/s]
# Draw a realistic photo of a dog.: 20.139774322509766

# %%
data = pd.DataFrame(data)
data
# Out:
#                               prompt      score
# 0   Draw a realistic photo of a cat.  26.941282
# 1   Draw a realistic photo of a cat.  26.689514
# 2   Draw a realistic photo of a cat.  28.381905
# 3   Draw a realistic photo of a cat.  27.159306
# 4   Draw a realistic photo of a cat.  27.855778
# 5   Draw a realistic photo of a cat.  27.731396
# 6   Draw a realistic photo of a cat.  26.555828
# 7   Draw a realistic photo of a cat.  27.467602
# 8   Draw a realistic photo of a cat.  27.056227
# 9   Draw a realistic photo of a cat.  26.074795
# 10                        Draw a cat  28.109989
# 11                        Draw a cat  27.181486
# 12                        Draw a cat  28.063492
# 13                        Draw a cat  27.581003
# 14                        Draw a cat  26.792368
# 15                        Draw a cat  25.883221
# 16                        Draw a cat  27.595066
# 17                        Draw a cat  27.134281
# 18                        Draw a cat  27.220333
# 19                        Draw a cat  29.248837
# 20                               cat  26.893536
# 21                               cat  20.413771
# 22                               cat  28.067102
# 23                               cat  20.126530
# 24                               cat  17.784081
# 25                               cat  27.820131
# 26                               cat  26.091835
# 27                               cat  27.251890
# 28                               cat  20.153049
# 29                               cat  18.186676
# 30  Draw a realistic photo of a dog.  20.072941
# 31  Draw a realistic photo of a dog.  20.035152
# 32  Draw a realistic photo of a dog.  19.988602
# 33  Draw a realistic photo of a dog.  19.391701
# 34  Draw a realistic photo of a dog.  19.793644
# 35  Draw a realistic photo of a dog.  20.654408
# 36  Draw a realistic photo of a dog.  20.193735
# 37  Draw a realistic photo of a dog.  21.033754
# 38  Draw a realistic photo of a dog.  20.905233
# 39  Draw a realistic photo of a dog.  20.139774

# %%
# Plotting the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='prompt', y='score', data=data)
plt.title('Boxplot of Scores by Prompt')
plt.xlabel('Prompt')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ## Exercise
# Append more prompts to the list above. Attempt to improve the score for the image showing a cat.

# %% [markdown]
# Measure which of the prompts produces the most photorealistic images.
